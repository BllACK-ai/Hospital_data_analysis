# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import re

# %%
ConCurrent = "Clean_DEPT.csv"
Data = pd.read_csv(ConCurrent)
Data
# Out:
#    Patient_ID        Full_Name  AGE SEX           DOB      Visit_Date  \
# 0    PT-0001        John Smith   45   M   1979-03-22      2024-01-11
# 1     pt0002          Jane Doe   46   F   05/11/1985              NA
# 2    PT_0003       Chidi Ngozi   61   F   1963/07/15     03-Jun-2025
# 3    pt-0004     Ibrahim Okoro   38   M           ??    Jul 21, 2023
# 4    PT0005*        Ada Mensah   72   F   0000-00-00    not recorded
# ..        ...              ...  ...  ..           ...             ...
# 95      P096               NaN   27   F   1996-09-27      2024-08-09
# 96      P097    Richard  Stone   67   M   1956-02-13      2024-03-20
# 97      P098       Diana  Paul   35   F          ---      1988-06-07
# 98      P099    Bashir  Ahmed    46   M   1979-11-11      2024-05-31
# 99      P100     Gloria  Davis   42   F   1981-02-22      2024-07-06
#
#            DEPT         Physician            Diagnosis   ICD-10  \
# 0            Er         Dr Bello              Malaria      A09
# ...

# %%
# Data.loc[[8,12,20,24,40], "SEX"] =  "F"
# Data.loc[[6,17,22,28,38,42], "SEX"] = "M"
# Data["SEX"] = Data["SEX"].str.strip()

# Data["AGE"] = Data["AGE"].astype("Int64") #the Int64 allows for no error when converting to int if column has NaN values
# Data.to_csv("Clean_Name.csv", index=False)



Data["Physician"] = Data["Physician"].str.replace("dr", "Dr")
Data["Physician"] = Data["Physician"].str.replace('"', "")
Data["Physician"] = Data["Physician"].str.strip()
Data["Physician"] = Data["Physician"].replace("Dr Bello", "Dr. Bello")
Data["Physician"] = Data["Physician"].replace("Dr. GarcÃ\xada", "Dr. Garxada")
Data["Physician"] = Data["Physician"].replace(["Dr. MÃ¼ller","Dr MÃ¼ller"], "Dr. Maller")
Data["Physician"] = Data["Physician"].replace("Dr O'Neil", "Dr. O'Neil")
Data["Physician"] = Data["Physician"].replace(["Dr Brown", "Dr.Brown", "Dr.brown", "Dr brown"], "Dr. Brown")
Data["Physician"] = Data["Physician"].replace(["Dr lee", "Dr Lee"], "Dr. Lee")
Data["Physician"] = Data["Physician"].replace(["Dr.green", "Dr.Green", "Dr Green"], "Dr. Green")
Data["Physician"] = Data["Physician"].replace(["Dr Adams", "Dr.Adams"], "Dr. Adams")
Data["Physician"] = Data["Physician"].replace(["Dr.White", "Dr.white"], "Dr. White")
Data["Physician"].unique()
# Out:
# array(['Dr. Bello', 'DR. JOHNSON', 'Dr. Garxada', 'Prof. Li',
#        'Dr. Maller', "Dr. O'Neil", 'Dr. Smith', 'Dr. Adaeze',
#        'Dr. A. Bello', 'Dr. Okoro', 'Dr. Adams', 'Dr. Brown', 'Dr. Lee',
#        'Dr. Green', 'Dr. White'], dtype=object)

# %%
# Data["AGE"] = Data["AGE"].replace(np.nan, 46) this works logically but
# Data["AGE"] = Data["AGE"].fillna(46) #but this is designed to handle missing values

# Data["SEX"].unique()
# Data["SEX"] = Data["SEX"].replace(["Male", "m", "male"], "M")
# Data["SEX"] = Data["SEX"].replace(["Female", "female", "f"], "F")
# Data["SEX"]

Data["Physician"].unique()
# Data
# Out:
# array(['Dr. Bello', 'DR. JOHNSON', 'Dr. Garxada', 'Prof. Li',
#        'Dr. Maller', "Dr. O'Neil", 'Dr. Smith', 'Dr. Adaeze',
#        'Dr. A. Bello', 'Dr. Okoro', 'Dr. Adams', 'Dr. Brown', 'Dr. Lee',
#        'Dr. Green', 'Dr. White'], dtype=object)

# %%
Data.to_csv("Clean_Physician.csv", index =False)
